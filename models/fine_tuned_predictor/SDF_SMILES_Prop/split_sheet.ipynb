# %%
import pandas as pd

# %%
split_file = "./SDF_SMILES_Prop/frontier_orbitals_111725mols.xlsx"
Dataset_file = "./SDF_SMILES_Prop/Dataset_prop.csv"
TestFinal_file = "./SDF_SMILES_Prop/TestFinal_prop.csv"

# %%
Dataset = pd.read_excel(split_file,sheet_name="Dataset")
TestFinal = pd.read_excel(split_file,sheet_name="TestFinal")

# %%
Dataset.to_csv(Dataset_file, index=False)
TestFinal.to_csv(TestFinal_file, index=False)
