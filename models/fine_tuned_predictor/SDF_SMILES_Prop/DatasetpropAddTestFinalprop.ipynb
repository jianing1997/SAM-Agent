# %%
import pandas as pd

# %%
Dataset_file = "./SDF_SMILES_Prop/Dataset_prop.csv"
TestFinal_file = "./SDF_SMILES_Prop/TestFinal_prop.csv"
SDF_file = "./SDF_SMILES_Prop/sdf_prop.csv"

# %%
Dataset = pd.read_csv(Dataset_file)
TestFinal = pd.read_csv(TestFinal_file)

# %%
pd.concat([Dataset, TestFinal], axis=0).to_csv(SDF_file, index=False)
