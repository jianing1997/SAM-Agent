# %%
import pandas as pd

# %%
# !pwd

# %%
testfinal_valid_smiles_file = r"./SDF_SMILES_Prop/TestFinal_valid_smiles_prop.csv"
testfinal_test_homo = r"./SDF_SMILES_Prop/TestFinal_test_homo.csv"
testfinal_test_lumo = r"./SDF_SMILES_Prop/TestFinal_test_lumo.csv"

# %%
testfinal_valid_smiles_data = pd.read_csv(testfinal_valid_smiles_file)

# %%
testfinal_valid_smiles_data.head(5)

# %%
testfinal_valid_smiles_data.loc[:,["SMILES", "HOMO(eV)"]].to_csv(testfinal_test_homo, index=False)

# %%
testfinal_valid_smiles_data.loc[:,["SMILES", "LUMO(eV)"]].to_csv(testfinal_test_lumo, index=False)
