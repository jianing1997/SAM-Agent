# %%
import pandas as pd

# %%
# !pwd

# %%
data_file = r"./0902_DM4ft.csv"

# %%
data = pd.read_csv(data_file)

# %%
# 假设你的 DataFrame 名字叫 data
data_filtered = data.dropna(subset=["SMILES", "TARGET"])  
data_filtered.to_csv(r"./0902_processed_DM4ft.csv", index=False)
