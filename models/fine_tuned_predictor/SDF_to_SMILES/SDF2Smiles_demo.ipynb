# %%
import argparse
import sys
from rdkit import Chem
from rdkit.Chem import AllChem
import os
import csv
from tqdm import tqdm

# %%
demo_data_file = "./SDF_to_SMILES/TestFinal/a26.sdf"

# %%
mol = Chem.MolFromMolFile(demo_data_file)
mol

# %%
smi = Chem.MolToSmiles(mol)
smi
